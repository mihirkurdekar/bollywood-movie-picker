# %%
from bs4 import BeautifulSoup as soup
import pandas as pd
import json
import requests
import re

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By

# Create a new instance of the Chrome driver
driver = webdriver.Chrome()

# Navigate to the IMDB homepage
url = "https://www.imdb.com"
driver.get(url)

# Find the search bar and enter your query
search_bar = driver.find_element(By.CSS_SELECTOR,"#title-search")
search_bar.send_keys("Bollywood")

# Click the search button
search_button = driver.find_element(By.CSS_SELECTOR,"#suggestion-submit-button")
search_button.click()

# Extract the movie titles from the results page
titles = driver.find_element(By.CSS_SELECTOR,"h3.findHeader")
for title in titles:
    print(title.text)

# Close the browser instance
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[19], line 13
#      10 driver.get(url)
#      12 # Find the search bar and enter your query
# ---> 13 search_bar = driver.find_element(By.CSS_SELECTOR,"#title-search")
#      14 search_bar.send_keys("Bollywood")
#      16 # Click the search button
#
# File ~/repos/bollywood-movie-picker/.venv/lib/python3.13/site-packages/selenium/webdriver/remote/webdriver.py:926, in WebDriver.find_element(self, by, value)
#     923         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     924     return elements[0]
# --> 926 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~/repos/bollywood-movie-picker/.venv/lib/python3.13/site-packages/selenium/webdriver/remote/webdriver.py:458, in WebDriver.execute(self, driver_command, params)
#     455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
# --> 458     self.error_handler.check_response(response)
#     459     response["value"] = self._unwrap_value(response.get("value", None))
#     460     return response
#
# File ~/repos/bollywood-movie-picker/.venv/lib/python3.13/site-packages/selenium/webdriver/remote/errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#title-search"}
#   (Session info: chrome=139.0.7258.155); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 0   chromedriver                        0x0000000100b62e00 cxxbridge1$str$ptr + 2742224
# 1   chromedriver                        0x0000000100b5ad00 cxxbridge1$str$ptr + 2709200
# 2   chromedriver                        0x00000001006a50b8 cxxbridge1$string$len + 90520
# 3   chromedriver                        0x00000001006ec5d8 cxxbridge1$string$len + 382648
# 4   chromedriver                        0x000000010072d980 cxxbridge1$string$len + 649824
# 5   chromedriver                        0x00000001006e08f4 cxxbridge1$string$len + 334292
# 6   chromedriver                        0x0000000100b26478 cxxbridge1$str$ptr + 2494024
# 7   chromedriver                        0x0000000100b296a4 cxxbridge1$str$ptr + 2506868
# 8   chromedriver                        0x0000000100b073b0 cxxbridge1$str$ptr + 2366848
# 9   chromedriver                        0x0000000100b29f4c cxxbridge1$str$ptr + 2509084
# 10  chromedriver                        0x0000000100af84a8 cxxbridge1$str$ptr + 2305656
# 11  chromedriver                        0x0000000100b49644 cxxbridge1$str$ptr + 2637844
# 12  chromedriver                        0x0000000100b497d0 cxxbridge1$str$ptr + 2638240
# 13  chromedriver                        0x0000000100b5a94c cxxbridge1$str$ptr + 2708252
# 14  libsystem_pthread.dylib             0x000000018c1efc0c _pthread_start + 136
# 15  libsystem_pthread.dylib             0x000000018c1eab80 thread_start + 8

# %%
page_soup=soup(res.text)

# %%
movies = []

# %%
while count < total_items:
  res = requests.get("https://www.imdb.com/search/title/?title_type=feature&countries=in&languages=hi&view=simple&ref_=adv_prv&start="+str(count+1))
  page_soup=soup(res.text)
  item_headers=page_soup.select('.lister-item-header')
  #if(count>100):
  #  break
  for item in item_headers:
    spans = item.findAll('span')
    movie_details = spans[1]
    name=movie_details.find('a').text
    year=movie_details.find('span').text
    #print(name)
    #print(year)
    movie = {'Name': name, 'Year': year}
    count += 1
    #print(movie)
    movies.append(movie)
    
#movies.reset_index()

# %%
#movies[49:51]

# %%
movies_df = pd.DataFrame(movies)

# %%
movies_df.to_csv("movies.csv", index=False)

# %%
movies_df.sample()
# Out:
#                Name    Year
# 10905  Vikram Vedha  (2022)

# %%
movies_df.sample()['Name'].values[0]
# Out:
# 'Jhutha Sach'
