# %%
#%pip install pyarrow

# %%
import pandas as pd

# %%
movies_imdb = pd.read_csv("title.akas.tsv", sep="\t", low_memory=False)

# %%
movies_imdb.columns
# Out:
# Index(['titleId', 'ordering', 'title', 'region', 'language', 'types',
#        'attributes', 'isOriginalTitle'],
#       dtype='object')

# %%
# get only Hindi movies and types imdbDisplay
movies_bollywood = movies_imdb[(movies_imdb['region'] == 'IN') & (movies_imdb['language'] == 'hi') & (movies_imdb['types'] == 'imdbDisplay')]

# %%
movies_bollywood.columns
# Out:
# Index(['titleId', 'ordering', 'title', 'region', 'language', 'types',
#        'attributes', 'isOriginalTitle'],
#       dtype='object')

# %%
movies_bollywood.describe()
# Out:
#           ordering  isOriginalTitle
# count  34786.00000          34786.0
# mean       9.87311              0.0
# std       10.03691              0.0
# min        2.00000              0.0
# 25%        4.00000              0.0
# 50%        7.00000              0.0
# 75%       11.00000              0.0
# max      189.00000              0.0

# %%
#count number of unique movies by titleId
movies_bollywood['titleId'].nunique()
# Out:
# 34488

# %%
movies_bollywood.to_parquet("bollywood_movies.parquet")

# %%
movies_bollywood.sample()
# Out:
#            titleId  ordering         title region language        types  \
# 1577921  tt0243061        10  Dragon Tales     IN       hi  imdbDisplay
#
#         attributes  isOriginalTitle
# 1577921         \N                0

# %%
movies_bollywood.sample()['title']
# Out:
# 44893713    Handa-kun
# Name: title, dtype: object
