# %%
import pandas as pd

# %%
movies_parquet = pd.read_parquet("../bollywood_movies.parquet")

# %%
movies_parquet.to_csv("movies_parquet.csv.gz", index=False, compression="gzip")

# %%
pd.read_csv("movies_parquet.csv.gz", compression="gzip").sample()
# Out:
#          titleId  ordering        title region language        types  \
# 26669  tt3663680         5  Union Bound     IN       hi  imdbDisplay
#
#       attributes  isOriginalTitle
# 26669         \N                0
